# %%
import pandas as pd

# %%
dataset=pd.read_csv("Tatacoffee13_21.csv")

# %%
dataset.tail()
# Out:
#             Date    Open    High     Low   Close
# 2220  2021-12-22  202.90  207.80  201.35  205.00
# 2221  2021-12-23  206.00  206.85  202.05  202.95
# 2222  2021-12-24  203.90  203.90  199.35  201.00
# 2223  2021-12-27  200.00  222.00  196.00  218.35
# 2224  2021-12-28  219.65  220.45  211.55  212.35

# %%
dataset["Open"].value_counts()
# Out:
# Open
# 91.00     11
# 90.50     10
# 88.00      9
# 92.50      9
# 91.50      9
#           ..
# 208.00     1
# 196.00     1
# 202.90     1
# 203.90     1
# 219.65     1
# Name: count, Length: 1401, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
timedata=pd.DataFrame()

# %%
timedata["Date"]=dataset["Date"]
timedata["Close"]=dataset["Close"]

# %%
data=timedata["Close"]

# %%
data_train=data.head(1500)

# %%
data_test=data.tail(509)

# %%
	
orders=[(1,0,2),(1,0,1),(2,0,1),(1,0,1)]

orderslist=[]
rscorelist=[]

for i in orders:

    orderslist.append(i)

    from statsmodels.tsa.arima.model import ARIMA
    model = ARIMA(data, order=i)
    model_fit = model.fit()

    y_pred = model_fit.predict(0, len(data)-1)

    from sklearn.metrics import r2_score
    r2 = r2_score(data, y_pred)

    rscorelist.append(r2)

    print("Order={} ,r2={}".format(i,r2))
# Out:
# Order=(1, 0, 2) ,r2=0.9944594472241093
# Order=(1, 0, 1) ,r2=0.9944589988258354
# Order=(2, 0, 1) ,r2=0.9944595582372973
# Order=(1, 0, 1) ,r2=0.9944589988258354

# %%
y_pred = model_fit.predict(len(data_train), len(data_train)+len(data_test)-1)

from sklearn.metrics import r2_score
r2 = r2_score(data_test, y_pred)

print("r2={}".format(r2))
# Out:
# r2=-0.36922024099259043

# %%
result=pd.DataFrame()

# %%
import pandas as pd

result = pd.DataFrame()

result.insert(0,"Order",orderslist)
result.insert(1,"R_score",rscorelist)

print(result)
# Out:
#        Order   R_score
# 0  (1, 0, 2)  0.994459
# 1  (1, 0, 1)  0.994459
# 2  (2, 0, 1)  0.994460
# 3  (1, 0, 1)  0.994459

# %%
model_fit.predict(len(data), len(data)+5)
# Out:
# 2225    212.115039
# 2226    212.225771
# 2227    212.336408
# 2228    212.446948
# 2229    212.557392
# 2230    212.667741
# Name: predicted_mean, dtype: float64
